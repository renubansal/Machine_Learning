# %%
iris = pd.read_csv("iris.data",names=['a','b','c','d','e'])

# %%
iris.dtypes
# Out:
# a    float64
# b    float64
# c    float64
# d    float64
# e     object
# dtype: object

# %%
iris.head()
# Out:
#      a    b    c    d            e
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.describe()
# Out:
#                 a           b           c           d
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(iris['a'])
plt.title("histogram")
plt.xlabel("classes")
plt.ylabel("count")
plt.show()

# %%
iris
# Out:
#        a    b    c    d               e
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
plt.scatter(iris.a,iris.b)
plt.show()

# %%
colors = {'Iris-setosa':'r', 'Iris-versicolor':'g', 
          'Iris-virginica':'b'}

# create a figure and axis
fig, ax = plt.subplots()
print(ax,fig)
size = len(iris.index)
print(size)
# plot each data-point
for i in range(size):
    ax.scatter(iris['a'][i], iris['b'][i], 
               color=colors[iris['e'][i]])
# set a title and labels
#ax.show()
fig.show()
#print(ax)
#plt.show()
#ax.set_title('Iris Dataset')
#ax.set_xlabel('sepal_length')
#ax.set_ylabel('sepal_width')
#ax.legend(['Iris-setosa','Iris-versicolor','Iris-virginica'])
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755) Figure(432x288)
# 150
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
iris.boxplot(column=['a', 'b','c','d'], rot = '90')

# %%
iris.describe()
# Out:
#                 a           b           c           d
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
#iris.pie(iris.e.value_counts())

# %%
iris['e'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: e, dtype: int64

# %%
iris['e'].value_counts().plot.pie()

# %%
x = [1,2,3]
y = [1,4,9]
z = [1,8,27]
ax = plt.subplot()
ax.plot(x,z,"red")
ax.plot(x,y,"blue")
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
z = [1,8,27]
ax = plt.subplot()
ax.plot(x,z)
plt.show()

# %%
iris['a'].corr(iris['b'])
# Out:
# -0.10936924995064937

# %%
iris.corr()
# Out:
#           a         b         c         d
# a  1.000000 -0.109369  0.871754  0.817954
# b -0.109369  1.000000 -0.420516 -0.356544
# c  0.871754 -0.420516  1.000000  0.962757
# d  0.817954 -0.356544  0.962757  1.000000

# %%
df = pd.read_csv("bank.csv",sep=';')

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df.marital.value_counts()
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
df.marital.nunique()
# Out:
# 3

# %%
x = df.marital.loc[df.y == 'yes'].value_counts()
y = df.marital.loc[df.y == 'no'].value_counts()


print(x)
print(y)
# Out:
# married     277
# single      167
# divorced     77
# Name: marital, dtype: int64
# married     2520
# single      1029
# divorced     451
# Name: marital, dtype: int64

# %%
import numpy as np
n_group = 3

fig,ax = plt.subplots()
index = np.arange(n_group)
bar_width = 0.3

bar1 = plt.bar(index,x.values,bar_width,color='r',label="yes")

bar2 = plt.bar(index + bar_width,y.values,bar_width,color='b',
               label="no")

# set title and labels 
plt.title('Marital Status Output-wise') 
#plt.xlabel('Marital Status')
#plt.legend()
#plt.xticks(index+bar_width,x.index,rotation='vertical')
#plt.ylabel('Frequency')
# Out:
# Text(0.5, 1.0, 'Marital Status Output-wise')
